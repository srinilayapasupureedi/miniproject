# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.optimizers import Adam
# Out:
# 2024-06-17 19:12:26.083200: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-17 19:12:26.644644: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-17 19:12:27.058757: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-17 19:12:33.587258: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load your dataset (replace 'your_dataset.csv' with the actual path to your dataset)
data = pd.read_csv('/home/rgukt/Desktop/pro/case1_considered/memory_usage.csv')

# Select relevant columns
data = data[['total_memory_mb', 'available_memory_mb', 'used_memory_mb', 'percent_memory']]

# Normalize the data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
seq_length = 10  # Length of sequences used for training

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(data_scaled, seq_length)

# Split into training and testing sets (80% train, 20% test)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
seq_length = 10  # Length of sequences used for training

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(data_scaled, seq_length)

# Split into training and testing sets (80% train, 20% test)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# Get the last sequence from the data
last_sequence = data_scaled[-seq_length:]

# Reshape for RNN input
last_sequence = last_sequence.reshape((1, seq_length, 4))

# Predict the next value
next_value_scaled = model.predict(last_sequence)

# Inverse transform to get actual value
next_value_actual = scaler.inverse_transform(next_value_scaled).flatten()

print(f'Predicted next values: {next_value_actual}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       5 last_sequence = last_sequence.reshape((1, seq_length, 4))
#       7 # Predict the next value
# ----> 8 next_value_scaled = model.predict(last_sequence)
#      10 # Inverse transform to get actual value
#      11 next_value_actual = scaler.inverse_transform(next_value_scaled).flatten()
#
# NameError: name 'model' is not defined

# %%
# Step 1: Import Libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.optimizers import Adam

# Step 2: Load and Preprocess Data
# Load your dataset (replace 'your_dataset.csv' with the actual path to your dataset)
data = pd.read_csv('/home/rgukt/Desktop/pro/case1_considered/memory_usage.csv')

# Select relevant columns
data = data[['total_memory_mb', 'available_memory_mb', 'used_memory_mb', 'percent_memory']]

# Normalize the data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# Step 3: Create Sequences for Training
seq_length = 10  # Length of sequences used for training

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(data_scaled, seq_length)

# Split into training and testing sets (80% train, 20% test)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Step 4: Build and Train the RNN Model
# Define the RNN model
model = Sequential()
model.add(SimpleRNN(50, activation='relu', input_shape=(seq_length, 4)))
model.add(Dense(4))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# Step 5: Make Predictions
# Get the last sequence from the data
last_sequence = data_scaled[-seq_length:]

# Reshape for RNN input
last_sequence = last_sequence.reshape((1, seq_length, 4))

# Predict the next value
next_value_scaled = model.predict(last_sequence)

# Inverse transform to get actual value
next_value_actual = scaler.inverse_transform(next_value_scaled).flatten()

print(f'Predicted next values: {next_value_actual}')
# Out:
# /home/rgukt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3836 - val_loss: 0.1499
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1197 - val_loss: 0.0622
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0504 - val_loss: 0.0095
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0191 - val_loss: 0.0104
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121 - val_loss: 0.0087
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0078 - val_loss: 0.0035
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - val_loss: 8.8381e-04
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018 - val_loss: 7.8530e-04
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018 - val_loss: 6.9462e-04
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019 - val_loss: 6.9565e-04
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 7.5263e-04
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 6.2907e-04
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 7.6887e-04
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 6.2295e-04
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 5.9558e-04
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 5.8759e-04
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 8.3955e-04
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 8.0612e-04
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 6.7065e-04
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 5.6627e-04
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 5.7701e-04
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 7.5547e-04
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 8.7341e-04
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1213e-04 - val_loss: 6.3977e-04
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 5.4409e-04
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 5.6232e-04
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9887e-04 - val_loss: 5.6619e-04
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 5.5345e-04
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 6.0958e-04
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 5.7033e-04
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 6.1411e-04
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 5.6297e-04
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6030e-04 - val_loss: 5.5690e-04
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0571e-04 - val_loss: 5.6151e-04
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 5.7226e-04
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1037e-04 - val_loss: 5.5726e-04
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8511e-04 - val_loss: 5.4922e-04
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6845e-04 - val_loss: 5.4551e-04
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 5.2987e-04
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 5.2761e-04
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - val_loss: 5.3514e-04
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0589e-04 - val_loss: 5.3826e-04
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 5.5082e-04
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9881e-04 - val_loss: 5.4003e-04
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 5.6009e-04
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 6.1860e-04
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 7.9114e-04
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 6.1541e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Predicted next values: [5853.6274  1921.3326  3599.4958    67.29017]
